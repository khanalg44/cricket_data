# %%
# Idea here is to read each ball and put that as a row in a daataframe.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os, glob, yaml

from utils import get_match_list

data_dir='../datasets/test_matches/tests_male/'

# %%
#'https://www.espncricinfo.com/series/india-in-australia-2020-21-1223867
#/australia-vs-india-1st-test-1223869/full-scorecard'
f = '1223869.yaml' # latest game
fil = data_dir+ f
data = yaml.load(open(fil))
data['innings']
# Out:
# [{'1st innings': {'team': 'India',
#    'deliveries': [{0.1: {'non_striker': 'MA Agarwal',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'PP Shaw'}},
#     {0.2: {'non_striker': 'MA Agarwal',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'PP Shaw',
#       'wicket': {'player_out': 'PP Shaw', 'kind': 'bowled'}}},
#     {0.3: {'non_striker': 'MA Agarwal',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {0.4: {'non_striker': 'MA Agarwal',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'CA Pujara'}},
#     {0.5: {'non_striker': 'CA Pujara',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MA Agarwal'}},
#     {0.6: {'non_striker': 'CA Pujara',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MA Agarwal'}},
#     {1.1: {'non_striker': 'MA Agarwal',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {1.2: {'non_striker': 'MA Agarwal',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {1.3: {'non_striker': 'MA Agarwal',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {1.4: {'non_striker': 'MA Agarwal',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {1.5: {'non_striker': 'MA Agarwal',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {1.6: {'non_striker': 'MA Agarwal',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {2.1: {'non_striker': 'CA Pujara',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MA Agarwal'}},
#     {2.2: {'non_striker': 'CA Pujara',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MA Agarwal'}},
#     {2.3: {'non_striker': 'CA Pujara',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'MA Agarwal'}},
#     {2.4: {'non_striker': 'MA Agarwal',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {2.5: {'non_striker': 'MA Agarwal',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {2.6: {'non_striker': 'MA Agarwal',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {3.1: {'non_striker': 'CA Pujara',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MA Agarwal'}},
#     {3.2: {'non_striker': 'CA Pujara',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MA Agarwal'}},
#     {3.3: {'non_striker': 'CA Pujara',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MA Agarwal'}},
#     {3.4: {'non_striker': 'CA Pujara',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MA Agarwal'}},
#     {3.5: {'non_striker': 'CA Pujara',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 3, 'batsman': 3},
#       'batsman': 'MA Agarwal'}},
#     {3.6: {'non_striker': 'MA Agarwal',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {4.1: {'non_striker': 'CA Pujara',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MA Agarwal'}},
#     {4.2: {'non_striker': 'CA Pujara',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'MA Agarwal'}},
#     {4.3: {'non_striker': 'MA Agarwal',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {4.4: {'non_striker': 'MA Agarwal',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'CA Pujara'}},
#     {4.5: {'non_striker': 'CA Pujara',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MA Agarwal'}},
#     {4.6: {'non_striker': 'CA Pujara',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MA Agarwal'}},
#     {5.1: {'non_striker': 'MA Agarwal',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {5.2: {'non_striker': 'MA Agarwal',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {5.3: {'non_striker': 'MA Agarwal',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {5.4: {'non_striker': 'MA Agarwal',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {5.5: {'non_striker': 'MA Agarwal',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {5.6: {'non_striker': 'MA Agarwal',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {6.1: {'non_striker': 'CA Pujara',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MA Agarwal'}},
#     {6.2: {'non_striker': 'CA Pujara',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MA Agarwal'}},
#     {6.3: {'non_striker': 'CA Pujara',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MA Agarwal'}},
#     {6.4: {'non_striker': 'CA Pujara',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MA Agarwal'}},
#     {6.5: {'non_striker': 'CA Pujara',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MA Agarwal'}},
#     {6.6: {'non_striker': 'CA Pujara',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MA Agarwal'}},
#     {7.1: {'non_striker': 'MA Agarwal',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {7.2: {'non_striker': 'MA Agarwal',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {7.3: {'non_striker': 'MA Agarwal',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {7.4: {'non_striker': 'MA Agarwal',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 1, 'total': 3, 'batsman': 2},
#       'extras': {'noballs': 1},
#       'batsman': 'CA Pujara'}},
#     {7.5: {'non_striker': 'MA Agarwal',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {7.6: {'non_striker': 'MA Agarwal',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {7.7: {'non_striker': 'MA Agarwal',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {8.1: {'non_striker': 'CA Pujara',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'MA Agarwal'}},
#     {8.2: {'non_striker': 'MA Agarwal',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {8.3: {'non_striker': 'MA Agarwal',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {8.4: {'non_striker': 'MA Agarwal',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#       'batsman': 'CA Pujara'}},
#     {8.5: {'non_striker': 'MA Agarwal',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {8.6: {'non_striker': 'MA Agarwal',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 3, 'batsman': 3},
#       'batsman': 'CA Pujara'}},
#     {9.1: {'non_striker': 'MA Agarwal',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {9.2: {'non_striker': 'MA Agarwal',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'CA Pujara'}},
#     {9.3: {'non_striker': 'CA Pujara',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MA Agarwal'}},
#     {9.4: {'non_striker': 'CA Pujara',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MA Agarwal'}},
#     {9.5: {'non_striker': 'CA Pujara',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MA Agarwal'}},
#     {9.6: {'non_striker': 'CA Pujara',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#       'batsman': 'MA Agarwal'}},
#     {10.1: {'non_striker': 'MA Agarwal',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {10.2: {'non_striker': 'MA Agarwal',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {10.3: {'non_striker': 'MA Agarwal',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {10.4: {'non_striker': 'MA Agarwal',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {10.5: {'non_striker': 'MA Agarwal',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {10.6: {'non_striker': 'MA Agarwal',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'CA Pujara'}},
#     {11.1: {'non_striker': 'MA Agarwal',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {11.2: {'non_striker': 'MA Agarwal',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {11.3: {'non_striker': 'MA Agarwal',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {11.4: {'non_striker': 'MA Agarwal',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {11.5: {'non_striker': 'MA Agarwal',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 3, 'batsman': 3},
#       'batsman': 'CA Pujara'}},
#     {11.6: {'non_striker': 'CA Pujara',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MA Agarwal'}},
#     {12.1: {'non_striker': 'MA Agarwal',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {12.2: {'non_striker': 'MA Agarwal',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {12.3: {'non_striker': 'MA Agarwal',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {12.4: {'non_striker': 'MA Agarwal',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {12.5: {'non_striker': 'MA Agarwal',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {12.6: {'non_striker': 'MA Agarwal',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {13.1: {'non_striker': 'CA Pujara',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MA Agarwal'}},
#     {13.2: {'non_striker': 'CA Pujara',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MA Agarwal'}},
#     {13.3: {'non_striker': 'CA Pujara',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MA Agarwal'}},
#     {13.4: {'non_striker': 'CA Pujara',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MA Agarwal'}},
#     {13.5: {'non_striker': 'CA Pujara',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MA Agarwal'}},
#     {13.6: {'non_striker': 'CA Pujara',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MA Agarwal'}},
#     {14.1: {'non_striker': 'MA Agarwal',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {14.2: {'non_striker': 'MA Agarwal',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {14.3: {'non_striker': 'MA Agarwal',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {14.4: {'non_striker': 'MA Agarwal',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {14.5: {'non_striker': 'MA Agarwal',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {14.6: {'non_striker': 'MA Agarwal',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {15.1: {'non_striker': 'CA Pujara',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#       'batsman': 'MA Agarwal'}},
#     {15.2: {'non_striker': 'CA Pujara',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MA Agarwal'}},
#     {15.3: {'non_striker': 'CA Pujara',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MA Agarwal'}},
#     {15.4: {'non_striker': 'CA Pujara',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MA Agarwal'}},
#     {15.5: {'non_striker': 'CA Pujara',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MA Agarwal'}},
#     {15.6: {'non_striker': 'CA Pujara',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#       'batsman': 'MA Agarwal'}},
#     {16.1: {'non_striker': 'MA Agarwal',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {16.2: {'non_striker': 'MA Agarwal',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {16.3: {'non_striker': 'MA Agarwal',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {16.4: {'non_striker': 'MA Agarwal',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {16.5: {'non_striker': 'MA Agarwal',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {16.6: {'non_striker': 'MA Agarwal',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {17.1: {'non_striker': 'CA Pujara',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'MA Agarwal'}},
#     {17.2: {'non_striker': 'MA Agarwal',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {17.3: {'non_striker': 'MA Agarwal',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {17.4: {'non_striker': 'MA Agarwal',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {17.5: {'non_striker': 'MA Agarwal',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {17.6: {'non_striker': 'MA Agarwal',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {18.1: {'non_striker': 'CA Pujara',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MA Agarwal',
#       'wicket': {'player_out': 'MA Agarwal', 'kind': 'bowled'}}},
#     {18.2: {'non_striker': 'CA Pujara',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {18.3: {'non_striker': 'CA Pujara',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {18.4: {'non_striker': 'CA Pujara',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {18.5: {'non_striker': 'CA Pujara',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {18.6: {'non_striker': 'CA Pujara',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {19.1: {'non_striker': 'V Kohli',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {19.2: {'non_striker': 'V Kohli',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {19.3: {'non_striker': 'V Kohli',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {19.4: {'non_striker': 'V Kohli',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {19.5: {'non_striker': 'V Kohli',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {19.6: {'non_striker': 'V Kohli',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {20.1: {'non_striker': 'CA Pujara',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {20.2: {'non_striker': 'CA Pujara',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {20.3: {'non_striker': 'CA Pujara',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#       'batsman': 'V Kohli'}},
#     {20.4: {'non_striker': 'CA Pujara',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {20.5: {'non_striker': 'CA Pujara',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {20.6: {'non_striker': 'CA Pujara',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {21.1: {'non_striker': 'V Kohli',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {21.2: {'non_striker': 'V Kohli',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {21.3: {'non_striker': 'V Kohli',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {21.4: {'non_striker': 'V Kohli',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {21.5: {'non_striker': 'V Kohli',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {21.6: {'non_striker': 'V Kohli',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'CA Pujara'}},
#     {22.1: {'non_striker': 'V Kohli',
#       'bowler': 'C Green',
#       'runs': {'extras': 1, 'total': 1, 'batsman': 0},
#       'extras': {'noballs': 1},
#       'batsman': 'CA Pujara'}},
#     {22.2: {'non_striker': 'V Kohli',
#       'bowler': 'C Green',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {22.3: {'non_striker': 'V Kohli',
#       'bowler': 'C Green',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {22.4: {'non_striker': 'V Kohli',
#       'bowler': 'C Green',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {22.5: {'non_striker': 'V Kohli',
#       'bowler': 'C Green',
#       'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#       'batsman': 'CA Pujara'}},
#     {22.6: {'non_striker': 'V Kohli',
#       'bowler': 'C Green',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {22.7: {'non_striker': 'V Kohli',
#       'bowler': 'C Green',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {23.1: {'non_striker': 'CA Pujara',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {23.2: {'non_striker': 'CA Pujara',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {23.3: {'non_striker': 'CA Pujara',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {23.4: {'non_striker': 'CA Pujara',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {23.5: {'non_striker': 'CA Pujara',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'V Kohli'}},
#     {23.6: {'non_striker': 'V Kohli',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {24.1: {'non_striker': 'CA Pujara',
#       'bowler': 'C Green',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {24.2: {'non_striker': 'CA Pujara',
#       'bowler': 'C Green',
#       'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#       'batsman': 'V Kohli'}},
#     {24.3: {'non_striker': 'CA Pujara',
#       'bowler': 'C Green',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {24.4: {'non_striker': 'CA Pujara',
#       'bowler': 'C Green',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {24.5: {'non_striker': 'CA Pujara',
#       'bowler': 'C Green',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {24.6: {'non_striker': 'CA Pujara',
#       'bowler': 'C Green',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {25.1: {'non_striker': 'V Kohli',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {25.2: {'non_striker': 'V Kohli',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {25.3: {'non_striker': 'V Kohli',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {25.4: {'non_striker': 'V Kohli',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {25.5: {'non_striker': 'V Kohli',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {25.6: {'non_striker': 'V Kohli',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {26.1: {'non_striker': 'CA Pujara',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {26.2: {'non_striker': 'CA Pujara',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {26.3: {'non_striker': 'CA Pujara',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {26.4: {'non_striker': 'CA Pujara',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {26.5: {'non_striker': 'CA Pujara',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {26.6: {'non_striker': 'CA Pujara',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {27.1: {'non_striker': 'V Kohli',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {27.2: {'non_striker': 'V Kohli',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {27.3: {'non_striker': 'V Kohli',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'CA Pujara'}},
#     {27.4: {'non_striker': 'CA Pujara',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {27.5: {'non_striker': 'CA Pujara',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {27.6: {'non_striker': 'CA Pujara',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {28.1: {'non_striker': 'V Kohli',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {28.2: {'non_striker': 'V Kohli',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {28.3: {'non_striker': 'V Kohli',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {28.4: {'non_striker': 'V Kohli',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'CA Pujara'}},
#     {28.5: {'non_striker': 'CA Pujara',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#       'batsman': 'V Kohli'}},
#     {28.6: {'non_striker': 'CA Pujara',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {29.1: {'non_striker': 'V Kohli',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {29.2: {'non_striker': 'V Kohli',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'CA Pujara'}},
#     {29.3: {'non_striker': 'CA Pujara',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {29.4: {'non_striker': 'CA Pujara',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'V Kohli'}},
#     {29.5: {'non_striker': 'V Kohli',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'CA Pujara'}},
#     {29.6: {'non_striker': 'CA Pujara',
#       'bowler': 'JR Hazlewood',
#       'runs': {'extras': 3, 'total': 3, 'batsman': 0},
#       'extras': {'legbyes': 3},
#       'batsman': 'V Kohli'}},
#     {30.1: {'non_striker': 'CA Pujara',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#       'batsman': 'V Kohli'}},
#     {30.2: {'non_striker': 'CA Pujara',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {30.3: {'non_striker': 'CA Pujara',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#       'batsman': 'V Kohli'}},
#     {30.4: {'non_striker': 'CA Pujara',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {30.5: {'non_striker': 'CA Pujara',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {30.6: {'non_striker': 'CA Pujara',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {31.1: {'non_striker': 'V Kohli',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#       'batsman': 'CA Pujara'}},
#     {31.2: {'non_striker': 'V Kohli',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {31.3: {'non_striker': 'V Kohli',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {31.4: {'non_striker': 'V Kohli',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {31.5: {'non_striker': 'V Kohli',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 3, 'batsman': 3},
#       'batsman': 'CA Pujara'}},
#     {31.6: {'non_striker': 'CA Pujara',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {32.1: {'non_striker': 'V Kohli',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {32.2: {'non_striker': 'V Kohli',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {32.3: {'non_striker': 'V Kohli',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {32.4: {'non_striker': 'V Kohli',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {32.5: {'non_striker': 'V Kohli',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {32.6: {'non_striker': 'V Kohli',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {33.1: {'non_striker': 'CA Pujara',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {33.2: {'non_striker': 'CA Pujara',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#       'batsman': 'V Kohli'}},
#     {33.3: {'non_striker': 'CA Pujara',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {33.4: {'non_striker': 'CA Pujara',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {33.5: {'non_striker': 'CA Pujara',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {33.6: {'non_striker': 'CA Pujara',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {34.1: {'non_striker': 'V Kohli',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {34.2: {'non_striker': 'V Kohli',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#       'batsman': 'CA Pujara'}},
#     {34.3: {'non_striker': 'V Kohli',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {34.4: {'non_striker': 'V Kohli',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {34.5: {'non_striker': 'V Kohli',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {34.6: {'non_striker': 'V Kohli',
#       'bowler': 'PJ Cummins',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {35.1: {'non_striker': 'CA Pujara',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {35.2: {'non_striker': 'CA Pujara',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {35.3: {'non_striker': 'CA Pujara',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {35.4: {'non_striker': 'CA Pujara',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {35.5: {'non_striker': 'CA Pujara',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {35.6: {'non_striker': 'CA Pujara',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'V Kohli'}},
#     {36.1: {'non_striker': 'CA Pujara',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#       'batsman': 'V Kohli'}},
#     {36.2: {'non_striker': 'CA Pujara',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {36.3: {'non_striker': 'CA Pujara',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {36.4: {'non_striker': 'CA Pujara',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {36.5: {'non_striker': 'CA Pujara',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {36.6: {'non_striker': 'CA Pujara',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {37.1: {'non_striker': 'V Kohli',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {37.2: {'non_striker': 'V Kohli',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {37.3: {'non_striker': 'V Kohli',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {37.4: {'non_striker': 'V Kohli',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {37.5: {'non_striker': 'V Kohli',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {37.6: {'non_striker': 'V Kohli',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {38.1: {'non_striker': 'CA Pujara',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {38.2: {'non_striker': 'CA Pujara',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {38.3: {'non_striker': 'CA Pujara',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {38.4: {'non_striker': 'CA Pujara',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {38.5: {'non_striker': 'CA Pujara',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {38.6: {'non_striker': 'CA Pujara',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {39.1: {'non_striker': 'V Kohli',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {39.2: {'non_striker': 'V Kohli',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {39.3: {'non_striker': 'V Kohli',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {39.4: {'non_striker': 'V Kohli',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {39.5: {'non_striker': 'V Kohli',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {39.6: {'non_striker': 'V Kohli',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {40.1: {'non_striker': 'CA Pujara',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'V Kohli'}},
#     {40.2: {'non_striker': 'V Kohli',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {40.3: {'non_striker': 'V Kohli',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {40.4: {'non_striker': 'V Kohli',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {40.5: {'non_striker': 'V Kohli',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {40.6: {'non_striker': 'V Kohli',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {41.1: {'non_striker': 'CA Pujara',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {41.2: {'non_striker': 'CA Pujara',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {41.3: {'non_striker': 'CA Pujara',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {41.4: {'non_striker': 'CA Pujara',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {41.5: {'non_striker': 'CA Pujara',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'V Kohli'}},
#     {41.6: {'non_striker': 'V Kohli',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {42.1: {'non_striker': 'CA Pujara',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {42.2: {'non_striker': 'CA Pujara',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {42.3: {'non_striker': 'CA Pujara',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {42.4: {'non_striker': 'CA Pujara',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {42.5: {'non_striker': 'CA Pujara',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {42.6: {'non_striker': 'CA Pujara',
#       'bowler': 'MA Starc',
#       'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#       'batsman': 'V Kohli'}},
#     {43.1: {'non_striker': 'V Kohli',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#       'batsman': 'CA Pujara'}},
#     {43.2: {'non_striker': 'V Kohli',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {43.3: {'non_striker': 'V Kohli',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {43.4: {'non_striker': 'V Kohli',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {43.5: {'non_striker': 'V Kohli',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {43.6: {'non_striker': 'V Kohli',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {44.1: {'non_striker': 'CA Pujara',
#       'bowler': 'C Green',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {44.2: {'non_striker': 'CA Pujara',
#       'bowler': 'C Green',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {44.3: {'non_striker': 'CA Pujara',
#       'bowler': 'C Green',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {44.4: {'non_striker': 'CA Pujara',
#       'bowler': 'C Green',
#       'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#       'batsman': 'V Kohli'}},
#     {44.5: {'non_striker': 'CA Pujara',
#       'bowler': 'C Green',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {44.6: {'non_striker': 'CA Pujara',
#       'bowler': 'C Green',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {45.1: {'non_striker': 'V Kohli',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'CA Pujara'}},
#     {45.2: {'non_striker': 'CA Pujara',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {45.3: {'non_striker': 'CA Pujara',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {45.4: {'non_striker': 'CA Pujara',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {45.5: {'non_striker': 'CA Pujara',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {45.6: {'non_striker': 'CA Pujara',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'V Kohli'}},
#     {46.1: {'non_striker': 'CA Pujara',
#       'bowler': 'C Green',
#       'runs': {'extras': 1, 'total': 1, 'batsman': 0},
#       'extras': {'noballs': 1},
#       'batsman': 'V Kohli'}},
#     {46.2: {'non_striker': 'CA Pujara',
#       'bowler': 'C Green',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {46.3: {'non_striker': 'CA Pujara',
#       'bowler': 'C Green',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {46.4: {'non_striker': 'CA Pujara',
#       'bowler': 'C Green',
#       'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#       'batsman': 'V Kohli'}},
#     {46.5: {'non_striker': 'CA Pujara',
#       'bowler': 'C Green',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {46.6: {'non_striker': 'CA Pujara',
#       'bowler': 'C Green',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {46.7: {'non_striker': 'CA Pujara',
#       'bowler': 'C Green',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {47.1: {'non_striker': 'V Kohli',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {47.2: {'non_striker': 'V Kohli',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#       'batsman': 'CA Pujara'}},
#     {47.3: {'non_striker': 'V Kohli',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#       'batsman': 'CA Pujara'}},
#     {47.4: {'non_striker': 'V Kohli',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {47.5: {'non_striker': 'V Kohli',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {47.6: {'non_striker': 'V Kohli',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'CA Pujara'}},
#     {48.1: {'non_striker': 'V Kohli',
#       'bowler': 'C Green',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {48.2: {'non_striker': 'V Kohli',
#       'bowler': 'C Green',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {48.3: {'non_striker': 'V Kohli',
#       'bowler': 'C Green',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {48.4: {'non_striker': 'V Kohli',
#       'bowler': 'C Green',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'CA Pujara'}},
#     {48.5: {'non_striker': 'CA Pujara',
#       'bowler': 'C Green',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {48.6: {'non_striker': 'CA Pujara',
#       'bowler': 'C Green',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'V Kohli'}},
#     {49.1: {'non_striker': 'V Kohli',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {49.2: {'non_striker': 'V Kohli',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara'}},
#     {49.3: {'non_striker': 'V Kohli',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#       'batsman': 'CA Pujara'}},
#     {49.4: {'non_striker': 'V Kohli',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'CA Pujara',
#       'wicket': {'player_out': 'CA Pujara',
#        'fielders': ['M Labuschagne'],
#        'kind': 'caught'}}},
#     {49.5: {'non_striker': 'V Kohli',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'AM Rahane'}},
#     {49.6: {'non_striker': 'V Kohli',
#       'bowler': 'NM Lyon',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'AM Rahane'}},
#     {50.1: {'non_striker': 'AM Rahane',
#       'bowler': 'C Green',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'V Kohli'}},
#     {50.2: {'non_striker': 'V Kohli',
#       'bowler': 'C Green',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'AM Rahane'}},
#     {50.3: {'non_striker': 'V Kohli',
#       'bowler': 'C Green',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'AM Rahane'}},
#     {50.4: {'non_striker': 'V Kohli',
#       'bowler': 'C Green',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'AM Rahane'}},
# ...
#       'batsman': 'MS Wade'}},
#     {4.1: {'non_striker': 'MS Wade',
#       'bowler': 'UT Yadav',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA Burns'}},
#     {4.2: {'non_striker': 'MS Wade',
#       'bowler': 'UT Yadav',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA Burns'}},
#     {4.3: {'non_striker': 'MS Wade',
#       'bowler': 'UT Yadav',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA Burns'}},
#     {4.4: {'non_striker': 'MS Wade',
#       'bowler': 'UT Yadav',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA Burns'}},
#     {4.5: {'non_striker': 'MS Wade',
#       'bowler': 'UT Yadav',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA Burns'}},
#     {4.6: {'non_striker': 'MS Wade',
#       'bowler': 'UT Yadav',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA Burns'}},
#     {5.1: {'non_striker': 'JA Burns',
#       'bowler': 'JJ Bumrah',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'MS Wade'}},
#     {5.2: {'non_striker': 'MS Wade',
#       'bowler': 'JJ Bumrah',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA Burns'}},
#     {5.3: {'non_striker': 'MS Wade',
#       'bowler': 'JJ Bumrah',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA Burns'}},
#     {5.4: {'non_striker': 'MS Wade',
#       'bowler': 'JJ Bumrah',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA Burns'}},
#     {5.5: {'non_striker': 'MS Wade',
#       'bowler': 'JJ Bumrah',
#       'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#       'batsman': 'JA Burns'}},
#     {5.6: {'non_striker': 'MS Wade',
#       'bowler': 'JJ Bumrah',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA Burns'}},
#     {6.1: {'non_striker': 'JA Burns',
#       'bowler': 'UT Yadav',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MS Wade'}},
#     {6.2: {'non_striker': 'JA Burns',
#       'bowler': 'UT Yadav',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MS Wade'}},
#     {6.3: {'non_striker': 'JA Burns',
#       'bowler': 'UT Yadav',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MS Wade'}},
#     {6.4: {'non_striker': 'JA Burns',
#       'bowler': 'UT Yadav',
#       'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#       'batsman': 'MS Wade'}},
#     {6.5: {'non_striker': 'JA Burns',
#       'bowler': 'UT Yadav',
#       'runs': {'extras': 0, 'total': 3, 'batsman': 3},
#       'batsman': 'MS Wade'}},
#     {6.6: {'non_striker': 'MS Wade',
#       'bowler': 'UT Yadav',
#       'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#       'batsman': 'JA Burns'}},
#     {7.1: {'non_striker': 'JA Burns',
#       'bowler': 'JJ Bumrah',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'MS Wade'}},
#     {7.2: {'non_striker': 'MS Wade',
#       'bowler': 'JJ Bumrah',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA Burns'}},
#     {7.3: {'non_striker': 'MS Wade',
#       'bowler': 'JJ Bumrah',
#       'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#       'batsman': 'JA Burns'}},
#     {7.4: {'non_striker': 'MS Wade',
#       'bowler': 'JJ Bumrah',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA Burns'}},
#     {7.5: {'non_striker': 'MS Wade',
#       'bowler': 'JJ Bumrah',
#       'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#       'batsman': 'JA Burns'}},
#     {7.6: {'non_striker': 'MS Wade',
#       'bowler': 'JJ Bumrah',
#       'runs': {'extras': 1, 'total': 1, 'batsman': 0},
#       'extras': {'noballs': 1},
#       'batsman': 'JA Burns'}},
#     {7.7: {'non_striker': 'MS Wade',
#       'bowler': 'JJ Bumrah',
#       'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#       'batsman': 'JA Burns'}},
#     {8.1: {'non_striker': 'JA Burns',
#       'bowler': 'UT Yadav',
#       'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#       'batsman': 'MS Wade'}},
#     {8.2: {'non_striker': 'JA Burns',
#       'bowler': 'UT Yadav',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MS Wade'}},
#     {8.3: {'non_striker': 'JA Burns',
#       'bowler': 'UT Yadav',
#       'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#       'batsman': 'MS Wade'}},
#     {8.4: {'non_striker': 'JA Burns',
#       'bowler': 'UT Yadav',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MS Wade'}},
#     {8.5: {'non_striker': 'JA Burns',
#       'bowler': 'UT Yadav',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MS Wade'}},
#     {8.6: {'non_striker': 'JA Burns',
#       'bowler': 'UT Yadav',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MS Wade'}},
#     {9.1: {'non_striker': 'MS Wade',
#       'bowler': 'R Ashwin',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA Burns'}},
#     {9.2: {'non_striker': 'MS Wade',
#       'bowler': 'R Ashwin',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA Burns'}},
#     {9.3: {'non_striker': 'MS Wade',
#       'bowler': 'R Ashwin',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA Burns'}},
#     {9.4: {'non_striker': 'MS Wade',
#       'bowler': 'R Ashwin',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA Burns'}},
#     {9.5: {'non_striker': 'MS Wade',
#       'bowler': 'R Ashwin',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA Burns'}},
#     {9.6: {'non_striker': 'MS Wade',
#       'bowler': 'R Ashwin',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA Burns'}},
#     {10.1: {'non_striker': 'JA Burns',
#       'bowler': 'JJ Bumrah',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MS Wade'}},
#     {10.2: {'non_striker': 'JA Burns',
#       'bowler': 'JJ Bumrah',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MS Wade'}},
#     {10.3: {'non_striker': 'JA Burns',
#       'bowler': 'JJ Bumrah',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'MS Wade'}},
#     {10.4: {'non_striker': 'MS Wade',
#       'bowler': 'JJ Bumrah',
#       'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#       'batsman': 'JA Burns'}},
#     {10.5: {'non_striker': 'MS Wade',
#       'bowler': 'JJ Bumrah',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA Burns'}},
#     {10.6: {'non_striker': 'MS Wade',
#       'bowler': 'JJ Bumrah',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA Burns'}},
#     {11.1: {'non_striker': 'JA Burns',
#       'bowler': 'R Ashwin',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MS Wade'}},
#     {11.2: {'non_striker': 'JA Burns',
#       'bowler': 'R Ashwin',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MS Wade'}},
#     {11.3: {'non_striker': 'JA Burns',
#       'bowler': 'R Ashwin',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MS Wade'}},
#     {11.4: {'non_striker': 'JA Burns',
#       'bowler': 'R Ashwin',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'MS Wade'}},
#     {11.5: {'non_striker': 'MS Wade',
#       'bowler': 'R Ashwin',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA Burns'}},
#     {11.6: {'non_striker': 'MS Wade',
#       'bowler': 'R Ashwin',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA Burns'}},
#     {12.1: {'non_striker': 'JA Burns',
#       'bowler': 'JJ Bumrah',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MS Wade'}},
#     {12.2: {'non_striker': 'JA Burns',
#       'bowler': 'JJ Bumrah',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MS Wade'}},
#     {12.3: {'non_striker': 'JA Burns',
#       'bowler': 'JJ Bumrah',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MS Wade'}},
#     {12.4: {'non_striker': 'JA Burns',
#       'bowler': 'JJ Bumrah',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MS Wade'}},
#     {12.5: {'non_striker': 'JA Burns',
#       'bowler': 'JJ Bumrah',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'MS Wade'}},
#     {12.6: {'non_striker': 'MS Wade',
#       'bowler': 'JJ Bumrah',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'JA Burns'}},
#     {13.1: {'non_striker': 'MS Wade',
#       'bowler': 'R Ashwin',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA Burns'}},
#     {13.2: {'non_striker': 'MS Wade',
#       'bowler': 'R Ashwin',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'JA Burns'}},
#     {13.3: {'non_striker': 'JA Burns',
#       'bowler': 'R Ashwin',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MS Wade'}},
#     {13.4: {'non_striker': 'JA Burns',
#       'bowler': 'R Ashwin',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MS Wade'}},
#     {13.5: {'non_striker': 'JA Burns',
#       'bowler': 'R Ashwin',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MS Wade'}},
#     {13.6: {'non_striker': 'JA Burns',
#       'bowler': 'R Ashwin',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MS Wade'}},
#     {14.1: {'non_striker': 'MS Wade',
#       'bowler': 'JJ Bumrah',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA Burns'}},
#     {14.2: {'non_striker': 'MS Wade',
#       'bowler': 'JJ Bumrah',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'JA Burns'}},
#     {14.3: {'non_striker': 'JA Burns',
#       'bowler': 'JJ Bumrah',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MS Wade'}},
#     {14.4: {'non_striker': 'JA Burns',
#       'bowler': 'JJ Bumrah',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MS Wade'}},
#     {14.5: {'non_striker': 'JA Burns',
#       'bowler': 'JJ Bumrah',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MS Wade'}},
#     {14.6: {'non_striker': 'JA Burns',
#       'bowler': 'JJ Bumrah',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MS Wade'}},
#     {15.1: {'non_striker': 'MS Wade',
#       'bowler': 'R Ashwin',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA Burns'}},
#     {15.2: {'non_striker': 'MS Wade',
#       'bowler': 'R Ashwin',
#       'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#       'batsman': 'JA Burns'}},
#     {15.3: {'non_striker': 'MS Wade',
#       'bowler': 'R Ashwin',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA Burns'}},
#     {15.4: {'non_striker': 'MS Wade',
#       'bowler': 'R Ashwin',
#       'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#       'batsman': 'JA Burns'}},
#     {15.5: {'non_striker': 'MS Wade',
#       'bowler': 'R Ashwin',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA Burns'}},
#     {15.6: {'non_striker': 'MS Wade',
#       'bowler': 'R Ashwin',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA Burns'}},
#     {16.1: {'non_striker': 'JA Burns',
#       'bowler': 'UT Yadav',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'MS Wade'}},
#     {16.2: {'non_striker': 'MS Wade',
#       'bowler': 'UT Yadav',
#       'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#       'batsman': 'JA Burns'}},
#     {16.3: {'non_striker': 'MS Wade',
#       'bowler': 'UT Yadav',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA Burns'}},
#     {16.4: {'non_striker': 'MS Wade',
#       'bowler': 'UT Yadav',
#       'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#       'batsman': 'JA Burns'}},
#     {16.5: {'non_striker': 'MS Wade',
#       'bowler': 'UT Yadav',
#       'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#       'batsman': 'JA Burns'}},
#     {16.6: {'non_striker': 'MS Wade',
#       'bowler': 'UT Yadav',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA Burns'}},
#     {17.1: {'non_striker': 'JA Burns',
#       'bowler': 'R Ashwin',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MS Wade'}},
#     {17.2: {'non_striker': 'JA Burns',
#       'bowler': 'R Ashwin',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'MS Wade',
#       'wicket': {'player_out': 'MS Wade', 'kind': 'run out'}}},
#     {17.3: {'non_striker': 'JA Burns',
#       'bowler': 'R Ashwin',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'M Labuschagne'}},
#     {17.4: {'non_striker': 'JA Burns',
#       'bowler': 'R Ashwin',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'M Labuschagne'}},
#     {17.5: {'non_striker': 'JA Burns',
#       'bowler': 'R Ashwin',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'M Labuschagne'}},
#     {17.6: {'non_striker': 'M Labuschagne',
#       'bowler': 'R Ashwin',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA Burns'}},
#     {18.1: {'non_striker': 'JA Burns',
#       'bowler': 'UT Yadav',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'M Labuschagne'}},
#     {18.2: {'non_striker': 'M Labuschagne',
#       'bowler': 'UT Yadav',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'JA Burns'}},
#     {18.3: {'non_striker': 'JA Burns',
#       'bowler': 'UT Yadav',
#       'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#       'batsman': 'M Labuschagne'}},
#     {18.4: {'non_striker': 'JA Burns',
#       'bowler': 'UT Yadav',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'M Labuschagne'}},
#     {18.5: {'non_striker': 'JA Burns',
#       'bowler': 'UT Yadav',
#       'runs': {'extras': 0, 'total': 2, 'batsman': 2},
#       'batsman': 'M Labuschagne'}},
#     {18.6: {'non_striker': 'JA Burns',
#       'bowler': 'UT Yadav',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'M Labuschagne'}},
#     {19.1: {'non_striker': 'M Labuschagne',
#       'bowler': 'R Ashwin',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA Burns'}},
#     {19.2: {'non_striker': 'M Labuschagne',
#       'bowler': 'R Ashwin',
#       'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#       'batsman': 'JA Burns'}},
#     {19.3: {'non_striker': 'M Labuschagne',
#       'bowler': 'R Ashwin',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'JA Burns'}},
#     {19.4: {'non_striker': 'JA Burns',
#       'bowler': 'R Ashwin',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'M Labuschagne'}},
#     {19.5: {'non_striker': 'JA Burns',
#       'bowler': 'R Ashwin',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'M Labuschagne',
#       'wicket': {'player_out': 'M Labuschagne',
#        'fielders': ['MA Agarwal'],
#        'kind': 'caught'}}},
#     {19.6: {'non_striker': 'SPD Smith',
#       'bowler': 'R Ashwin',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA Burns'}},
#     {20.1: {'non_striker': 'JA Burns',
#       'bowler': 'UT Yadav',
#       'runs': {'extras': 0, 'total': 1, 'batsman': 1},
#       'batsman': 'SPD Smith'}},
#     {20.2: {'non_striker': 'SPD Smith',
#       'bowler': 'UT Yadav',
#       'runs': {'extras': 0, 'total': 4, 'batsman': 4},
#       'batsman': 'JA Burns'}},
#     {20.3: {'non_striker': 'SPD Smith',
#       'bowler': 'UT Yadav',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA Burns'}},
#     {20.4: {'non_striker': 'SPD Smith',
#       'bowler': 'UT Yadav',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA Burns'}},
#     {20.5: {'non_striker': 'SPD Smith',
#       'bowler': 'UT Yadav',
#       'runs': {'extras': 0, 'total': 0, 'batsman': 0},
#       'batsman': 'JA Burns'}},
#     {20.6: {'non_striker': 'SPD Smith',
#       'bowler': 'UT Yadav',
#       'runs': {'extras': 0, 'total': 6, 'batsman': 6},
#       'batsman': 'JA Burns'}}]}}]

# %%
def read_ball_by_ball(f, data_dir='./'):
    fil=os.path.join(data_dir, f )
    match_id = f.split('/')[-1].split('.')[0]
    
    with open(fil, 'r') as stream:
        try:
            data = yaml.safe_load(stream)
        except yaml.YAMLError as exc:
            print(exc)
    try:
        match_date=data['info']['dates'][0].strftime('%Y-%m-%d')
    except:
        match_date=data['info']['dates'][0]
    
    num_inns = len(data['innings'])
    inns  = {list(data['innings'][i].keys())[0]: list(data['innings'][i].values())[0]['team']
             for i in range(num_inns) }
    
    teams  = data['info']['teams']
    winner = data['info']['outcome'].get('winner', None)
    draw   = False
    if winner is None:
        draw = True
        
    toss_winner = data['info']['toss'].get('winner', None)
    
    score_card = []
    
    for i, inn in enumerate(inns):
        batting_team = inns[inn]
        bowling_team = [team for team in  teams if team != batting_team][0]
        
        for delivery in data['innings'][i][inn]['deliveries']:
            deliv    = list(delivery.items())[0]
            ball     = deliv[0]
            ov_num   = int(str(ball+1).split('.')[0])
            
            batsman  = deliv[1]['batsman'].strip()
            bowler   = deliv[1]['bowler'].strip()
            non_striker = deliv[1]['non_striker']

            runs_bat = deliv[1]['runs'].get('batsman', 0)
            runs_ext = deliv[1]['runs'].get('extras',  0)
            runs_tot = deliv[1]['runs'].get('total',   0)
            
            runs_type={str(i)+'s':0 for i in range(8)}
            runs_type[str(runs_bat)+'s'] += 1
            
            wd = 0; nb = 0; lb = 0; byes = 0;
            if 'extras' in deliv[1]:
                wd = deliv[1]['extras'].get('wides', 0)
                nb = deliv[1]['extras'].get('noballs', 0)
                lb = deliv[1]['extras'].get('legbyes', 0)
                byes = deliv[1]['extras'].get('byes', 0)
            exts = {'wd':wd, 'nb':nb, 'lb':lb, 'byes':byes}
            
            wkt = False; player_out = ''; out_kind = ''; out_fielder = ''
            
            if 'wicket' in deliv[1]:
                wkt = True
                player_out = deliv[1]['wicket']['player_out']
                out_kind   = deliv[1]['wicket']['kind']
                if deliv[1]['wicket'].get('fielders', None):
                    out_fielder = deliv[1]['wicket']['fielders']
                    
            info_deliv = [inn, ball, batsman, bowler, non_striker, runs_bat, runs_ext, runs_tot, runs_type,
                          exts, wkt, player_out, out_kind, out_fielder, batting_team, bowling_team,
                          winner, toss_winner, draw, match_date, match_id]
            score_card.append( info_deliv )
    
    columns = ["innings", "over", "batsman", "bowler", "non_striker", "runs_bat", "runs_ext", "runs_tot", "runs_type",
               "extra", "wicket", "player_out", "out_kind", "out_fielder", "batting_team", "bowling_team",
               "winner", "toss_winner", "draw", "match_date", "match_id"]
    df = pd.DataFrame(score_card, columns = columns)

    return df

f = data_dir+'1223869.yaml'
df = read_ball_by_ball(f)
print (df.columns)
df.head(2)
# Out:
# Index(['innings', 'over', 'batsman', 'bowler', 'non_striker', 'runs_bat',
#        'runs_ext', 'runs_tot', 'runs_type', 'extra', 'wicket', 'player_out',
#        'out_kind', 'out_fielder', 'batting_team', 'bowling_team', 'winner',
#        'toss_winner', 'draw', 'match_date', 'match_id'],
#       dtype='object')
#        innings  over  batsman    bowler non_striker  runs_bat  runs_ext  \
# 0  1st innings   0.1  PP Shaw  MA Starc  MA Agarwal         0         0
# 1  1st innings   0.2  PP Shaw  MA Starc  MA Agarwal         0         0
#
#    runs_tot                                          runs_type  \
# 0         0  {'0s': 1, '1s': 0, '2s': 0, '3s': 0, '4s': 0, ...
# 1         0  {'0s': 1, '1s': 0, '2s': 0, '3s': 0, '4s': 0, ...
#
#                                     extra  ...  player_out out_kind  \
# 0  {'wd': 0, 'nb': 0, 'lb': 0, 'byes': 0}  ...
# 1  {'wd': 0, 'nb': 0, 'lb': 0, 'byes': 0}  ...     PP Shaw   bowled
#
#   out_fielder batting_team bowling_team     winner toss_winner   draw  \
# 0                    India    Australia  Australia       India  False
# 1                    India    Australia  Australia       India  False
#
#    match_date match_id
# 0  2020-12-17  1223869
# 1  2020-12-17  1223869
#
# [2 rows x 21 columns]

# %%
def print_scorecard(f, data_dir='./'):
    df = read_ball_by_ball(f, data_dir=data_dir)
    
    all_inns = df['innings'].unique()
    
    winner = df['winner'].unique()[0]
    draw   = df['draw'].values[0]
    toss_winner = df['toss_winner'].unique()[0]
    print (winner, toss_winner, draw)
    
    batting_card = []
    bowling_card = []
    for inn in all_inns:
        print (inn)
        dfi = df[df['innings']==inn]
        
        batting_team = dfi['batting_team'].unique()[0]
        bowling_team = dfi['bowling_team'].unique()[0]
        
        match_date   = dfi['match_date'].values[0]
        match_id     = dfi['match_id'].values[0] 
        

        all_batsman = dfi['batsman'].unique()
        all_bowler  = dfi['bowler'].unique()
        all_players = list(all_batsman) + list(all_bowler)
        #print (all_players)
        all_bat_out = [d for d in dfi['player_out'] if d]
        runs_tot = dfi['runs_tot'].sum()
        wkts_tot = dfi['wicket'].sum()
        #print (inn, runs_tot, wkts_tot)
        for player in all_players:
            
            dfbat = dfi[dfi['batsman']==player]
            if (dfbat.shape[0]>0) or (player in all_bat_out) :  # second condition if batsman runout for 0(0)
                runs = dfbat['runs_bat'].sum()
                balls = dfbat['over'].shape[0] - sum([d['wd'] for d in dfbat['extra']])
                not_out = [False if player in all_bat_out else True][0]

                runs_type = [sum([d[str(i)+'s'] for d in dfbat['runs_type']]) for i in range(8) ]
                zeros, ones, twos, threes, fours, fives, sixes, sevens = runs_type
                
                win  = (winner == batting_team)
                toss = (toss_winner == batting_team)

                info_bat = [player, runs, balls, not_out, zeros, ones, twos, threes, fours, fives, sixes, sevens,
                            inn, batting_team, bowling_team, match_date, match_id, win, draw, toss,
                            runs_tot, wkts_tot]
                
                batting_card.append( info_bat )
            
            dfbwl = dfi[dfi['bowler']==player]
            if dfbwl.shape[0]>0:
                overs = dfbwl['over'].values
                runs_bat = dfbwl['runs_bat'].values
                runs_ext = dfbwl['runs_ext'].values
                runs_tot = dfbwl['runs_tot'].values
                
                runs_type = [sum( [d[str(i)+'s'] for d in dfbwl['runs_type']] ) for i in range(8) ]
                zeros, ones, twos, threes, fours, fives, sixes, sevens = runs_type
                
                wide_balls = [d['wd'] for d in dfbwl['extra'] if d['wd'] !=0]
                no_balls   = [d['nb'] for d in dfbwl['extra'] if d['nb'] !=0]
                wide_runs  = sum(wide_balls)
                noball_runs = sum(no_balls)

                total_balls_bowled = dfbwl.over.count() - len(wide_balls) - len(no_balls)
                ov, balls_ = (total_balls_bowled//6, total_balls_bowled%6)
                total_runs_given   = dfbwl.runs_tot.sum() - sum([d['lb']+d['byes'] for d in dfbwl['extra']])
                
                ov, balls_ = (total_balls_bowled//6, total_balls_bowled%6)

                ov_dict = {(ov+1):{'R':0, 'W':0} for ov in dfbwl.over.astype(int).unique()}
                for i in range(len(overs)):
                    ov_int = int(dfbwl.over.iloc[i])+1
                    runs_  = dfbwl.runs_tot.iloc[i] # - dfbwl.extra.iloc[i]['lb'] - dfbwl.extra.iloc[i]['byes']
                    wkts_  = dfbwl.wicket.iloc[i].astype(int)
                    ov_dict[ov_int]['R'] += runs_
                    ov_dict[ov_int]['W'] += wkts_
                    
                maidens = sum([1 for i in ov_dict if ov_dict[i]['R']==0])
                wds = sum([ d['wd'] for d in dfbwl['extra'] ] )
                nbs = sum([ d['nb'] for d in dfbwl['extra'] ] )
                
                wkt_taken = dfbwl['wicket'].sum() -\
                        dfbwl[dfbwl['out_kind']=='run out'].shape[0] -\
                        dfbwl[dfbwl['out_kind']=='retired hurt'].shape[0]

                ov = str(ov)
                if balls_>0:
                    ov = str(ov)+'.'+str(balls_)
                    
                win  = (winner == bowling_team)
                toss = (toss_winner == bowling_team)
                    
                info_ball = [player, ov, maidens, total_runs_given, wkt_taken, inn, ov_dict,
                             zeros, ones, twos, threes, fours, fives, sixes, sevens, wds, nbs, 
                             match_date, match_id, win, draw, toss ]
                
                bowling_card.append( info_ball )

            #print (batsman, runs, balls, not_out, zeros, ones, twos, threes, fours, fives, sixes,
            #batting_team, bowling_team, match_date, match_id, win, draw, toss)


    col_bat = ['batsman', 'runs', 'BF', 'NO', '0s', '1s', '2s', '3s', '4s', '5s', '6s', '7s',
               'innings', 'Team', 'Against', 'date',  'match_id', 'Win', 'Draw', 'Toss',
               'runs_tot_inn', 'wkts_tot_inn']
    df_bat  = pd.DataFrame(batting_card, columns=col_bat)
    
    col_bowl = ['bowler', 'O', 'M', 'R', 'W', 'innings', 'all_overs',
               '0s', '1s', '2s', '3s', '4s', '5s', '6s', '7s', 'wds', 'nbs',
               'date', 'match_id', 'Win', 'draw', 'Toss']
    df_bowl = pd.DataFrame(bowling_card, columns=col_bowl)
    
    return df_bat, df_bowl


f = data_dir+'1223869.yaml'
df_bat, df_bowl = print_scorecard(f)
df_bat
# Out:
# Australia India False
# 1st innings
# 2nd innings
# 3rd innings
# 4th innings
#            batsman  runs   BF     NO   0s  1s  2s  3s  4s  5s  ...  \
# 0          PP Shaw     0    2  False    2   0   0   0   0   0  ...
# 1        CA Pujara    43  160  False  136  12   7   3   2   0  ...
# 2       MA Agarwal    17   40  False   32   4   1   1   2   0  ...
# 3          V Kohli    74  180  False  139  25   7   1   8   0  ...
# 4        AM Rahane    42   92  False   72  12   3   2   3   0  ...
# 5        GH Vihari    16   25  False   19   2   0   2   2   0  ...
# 6          WP Saha     9   26  False   22   1   2   0   1   0  ...
# 7         R Ashwin    15   20  False   12   4   2   1   1   0  ...
# 8         UT Yadav     6   13  False   10   2   0   0   1   0  ...
# 9        JJ Bumrah     4    7   True    6   0   0   0   1   0  ...
# 10  Mohammed Shami     0    1  False    1   0   0   0   0   0  ...
# 11         MS Wade     8   51  False   46   4   0   0   1   0  ...
# 12        JA Burns     8   41  False   36   2   3   0   0   0  ...
# 13   M Labuschagne    47  119  False   95  15   2   0   7   0  ...
# 14       SPD Smith     1   29  False   28   1   0   0   0   0  ...
# 15         TM Head     7   20  False   15   3   2   0   0   0  ...
# 16         C Green    11   24  False   17   5   1   0   1   0  ...
# 17        TD Paine    73   99   True   64  18   6   1  10   0  ...
# 18      PJ Cummins     0    3  False    3   0   0   0   0   0  ...
# 19        MA Starc    15   16  False    8   4   2   1   1   0  ...
# 20         NM Lyon    10   21  False   15   4   1   0   1   0  ...
# 21    JR Hazlewood     8   10  False    8   0   0   0   2   0  ...
# 22         PP Shaw     4    4  False    2   1   0   1   0   0  ...
# 23      MA Agarwal     9   40  False   36   1   2   0   1   0  ...
# 24       JJ Bumrah     2   17  False   16   0   1   0   0   0  ...
# 25       CA Pujara     0    8  False    8   0   0   0   0   0  ...
# 26         V Kohli     4    8  False    7   0   0   0   1   0  ...
# 27       AM Rahane     0    4  False    4   0   0   0   0   0  ...
# 28       GH Vihari     8   22  False   18   2   1   0   1   0  ...
# 29         WP Saha     4   15  False   13   0   2   0   0   0  ...
# 30        R Ashwin     0    1  False    1   0   0   0   0   0  ...
# 31        UT Yadav     4    5   True    4   0   0   0   1   0  ...
# 32  Mohammed Shami     1    4  False    3   1   0   0   0   0  ...
# 33         MS Wade    33   53  False   39   6   2   1   5   0  ...
# 34        JA Burns    51   63   True   44   5   6   0   7   0  ...
# 35   M Labuschagne     6   10  False    6   2   2   0   0   0  ...
# 36       SPD Smith     1    1   True    0   1   0   0   0   0  ...
#
#         innings       Team    Against        date match_id    Win   Draw  \
# 0   1st innings      India  Australia  2020-12-17  1223869  False  False
# 1   1st innings      India  Australia  2020-12-17  1223869  False  False
# 2   1st innings      India  Australia  2020-12-17  1223869  False  False
# 3   1st innings      India  Australia  2020-12-17  1223869  False  False
# 4   1st innings      India  Australia  2020-12-17  1223869  False  False
# 5   1st innings      India  Australia  2020-12-17  1223869  False  False
# 6   1st innings      India  Australia  2020-12-17  1223869  False  False
# 7   1st innings      India  Australia  2020-12-17  1223869  False  False
# 8   1st innings      India  Australia  2020-12-17  1223869  False  False
# 9   1st innings      India  Australia  2020-12-17  1223869  False  False
# 10  1st innings      India  Australia  2020-12-17  1223869  False  False
# 11  2nd innings  Australia      India  2020-12-17  1223869   True  False
# 12  2nd innings  Australia      India  2020-12-17  1223869   True  False
# 13  2nd innings  Australia      India  2020-12-17  1223869   True  False
# 14  2nd innings  Australia      India  2020-12-17  1223869   True  False
# 15  2nd innings  Australia      India  2020-12-17  1223869   True  False
# 16  2nd innings  Australia      India  2020-12-17  1223869   True  False
# 17  2nd innings  Australia      India  2020-12-17  1223869   True  False
# 18  2nd innings  Australia      India  2020-12-17  1223869   True  False
# 19  2nd innings  Australia      India  2020-12-17  1223869   True  False
# 20  2nd innings  Australia      India  2020-12-17  1223869   True  False
# 21  2nd innings  Australia      India  2020-12-17  1223869   True  False
# 22  3rd innings      India  Australia  2020-12-17  1223869  False  False
# 23  3rd innings      India  Australia  2020-12-17  1223869  False  False
# 24  3rd innings      India  Australia  2020-12-17  1223869  False  False
# 25  3rd innings      India  Australia  2020-12-17  1223869  False  False
# 26  3rd innings      India  Australia  2020-12-17  1223869  False  False
# 27  3rd innings      India  Australia  2020-12-17  1223869  False  False
# 28  3rd innings      India  Australia  2020-12-17  1223869  False  False
# 29  3rd innings      India  Australia  2020-12-17  1223869  False  False
# 30  3rd innings      India  Australia  2020-12-17  1223869  False  False
# 31  3rd innings      India  Australia  2020-12-17  1223869  False  False
# 32  3rd innings      India  Australia  2020-12-17  1223869  False  False
# 33  4th innings  Australia      India  2020-12-17  1223869   True  False
# 34  4th innings  Australia      India  2020-12-17  1223869   True  False
# 35  4th innings  Australia      India  2020-12-17  1223869   True  False
# 36  4th innings  Australia      India  2020-12-17  1223869   True  False
#
#      Toss  runs_tot_inn  wkts_tot_inn
# 0    True           244            10
# 1    True           244            10
# 2    True           244            10
# 3    True           244            10
# 4    True           244            10
# 5    True           244            10
# 6    True           244            10
# 7    True           244            10
# 8    True           244            10
# 9    True           244            10
# 10   True           244            10
# 11  False           191            10
# 12  False           191            10
# 13  False           191            10
# 14  False           191            10
# 15  False           191            10
# 16  False           191            10
# 17  False           191            10
# 18  False           191            10
# 19  False           191            10
# 20  False           191            10
# 21  False           191            10
# 22   True            36            10
# 23   True            36            10
# 24   True            36            10
# 25   True            36            10
# 26   True            36            10
# 27   True            36            10
# 28   True            36            10
# 29   True            36            10
# 30   True            36            10
# 31   True            36            10
# 32   True            36            10
# 33  False            93             2
# 34  False            93             2
# 35  False            93             2
# 36  False            93             2
#
# [37 rows x 22 columns]

# %%
df_bowl

# %%
f = data_dir+'249223.yaml'
df = read_ball_by_ball(f)
df
# Out:
#           innings  over     batsman       bowler non_striker  runs_bat  \
# 0     1st innings   0.1  AJ Strauss        B Lee     AN Cook         0
# 1     1st innings   0.2  AJ Strauss        B Lee     AN Cook         0
# 2     1st innings   0.3  AJ Strauss        B Lee     AN Cook         0
# 3     1st innings   0.4  AJ Strauss        B Lee     AN Cook         0
# 4     1st innings   0.5  AJ Strauss        B Lee     AN Cook         0
# ...           ...   ...         ...          ...         ...       ...
# 2655  4th innings  32.1   MJ Clarke  JM Anderson  MEK Hussey         1
# 2656  4th innings  32.2  MEK Hussey  JM Anderson   MJ Clarke         2
# 2657  4th innings  32.3  MEK Hussey  JM Anderson   MJ Clarke         0
# 2658  4th innings  32.4  MEK Hussey  JM Anderson   MJ Clarke         4
# 2659  4th innings  32.5  MEK Hussey  JM Anderson   MJ Clarke         1
#
#       runs_ext  runs_tot                                          runs_type  \
# 0            0         0  {'0s': 1, '1s': 0, '2s': 0, '3s': 0, '4s': 0, ...
# 1            0         0  {'0s': 1, '1s': 0, '2s': 0, '3s': 0, '4s': 0, ...
# 2            0         0  {'0s': 1, '1s': 0, '2s': 0, '3s': 0, '4s': 0, ...
# 3            0         0  {'0s': 1, '1s': 0, '2s': 0, '3s': 0, '4s': 0, ...
# 4            0         0  {'0s': 1, '1s': 0, '2s': 0, '3s': 0, '4s': 0, ...
# ...        ...       ...                                                ...
# 2655         0         1  {'0s': 0, '1s': 1, '2s': 0, '3s': 0, '4s': 0, ...
# 2656         0         2  {'0s': 0, '1s': 0, '2s': 1, '3s': 0, '4s': 0, ...
# 2657         0         0  {'0s': 1, '1s': 0, '2s': 0, '3s': 0, '4s': 0, ...
# 2658         0         4  {'0s': 0, '1s': 0, '2s': 0, '3s': 0, '4s': 1, ...
# 2659         0         1  {'0s': 0, '1s': 1, '2s': 0, '3s': 0, '4s': 0, ...
#
#                                        extra  ...  player_out out_kind  \
# 0     {'wd': 0, 'nb': 0, 'lb': 0, 'byes': 0}  ...
# 1     {'wd': 0, 'nb': 0, 'lb': 0, 'byes': 0}  ...
# 2     {'wd': 0, 'nb': 0, 'lb': 0, 'byes': 0}  ...
# 3     {'wd': 0, 'nb': 0, 'lb': 0, 'byes': 0}  ...
# 4     {'wd': 0, 'nb': 0, 'lb': 0, 'byes': 0}  ...
# ...                                      ...  ...         ...      ...
# 2655  {'wd': 0, 'nb': 0, 'lb': 0, 'byes': 0}  ...
# 2656  {'wd': 0, 'nb': 0, 'lb': 0, 'byes': 0}  ...
# 2657  {'wd': 0, 'nb': 0, 'lb': 0, 'byes': 0}  ...
# 2658  {'wd': 0, 'nb': 0, 'lb': 0, 'byes': 0}  ...
# 2659  {'wd': 0, 'nb': 0, 'lb': 0, 'byes': 0}  ...
#
#      out_fielder batting_team bowling_team     winner toss_winner   draw  \
# 0                     England    Australia  Australia     England  False
# 1                     England    Australia  Australia     England  False
# 2                     England    Australia  Australia     England  False
# 3                     England    Australia  Australia     England  False
# 4                     England    Australia  Australia     England  False
# ...          ...          ...          ...        ...         ...    ...
# 2655                Australia      England  Australia     England  False
# 2656                Australia      England  Australia     England  False
# 2657                Australia      England  Australia     England  False
# 2658                Australia      England  Australia     England  False
# 2659                Australia      England  Australia     England  False
#
#       match_date match_id
# 0     2006-12-01   249223
# 1     2006-12-01   249223
# 2     2006-12-01   249223
# 3     2006-12-01   249223
# 4     2006-12-01   249223
# ...          ...      ...
# 2655  2006-12-01   249223
# 2656  2006-12-01   249223
# 2657  2006-12-01   249223
# 2658  2006-12-01   249223
# 2659  2006-12-01   249223
#
# [2660 rows x 21 columns]
